# %%
from pathlib import Path
from control_panel import run_dashboard_calculation

# Pad naar je inputbestand (pas deze aan)
input_file = Path("jouw_inputbestand.xlsx")

# Lees bestand als bytes (zoals de functie verwacht)
file_content = input_file.read_bytes()

# Parameters
crop = "Tomaat"            # pas aan naar geldige crop-naam
flow_mode = "High Flow"    # of "Low Flow"
years = 1
geo_power = None           # of bv. 2500.0

# Run
df_results, kpis, flow_min, flow_max = run_dashboard_calculation(
    file_content=file_content,
    crop=crop,
    flow_mode=flow_mode,
    years=years,
    geo_power=geo_power,
)

# Bekijk output
display(df_results.head())
print("KPIs:", kpis)
print("Flow min/max:", flow_min, flow_max)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 from control_panel import run_dashboard_calculation
#       4 # Pad naar je inputbestand (pas deze aan)
#       5 input_file = Path("jouw_inputbestand.xlsx")
#
# ModuleNotFoundError: No module named 'control_panel'
